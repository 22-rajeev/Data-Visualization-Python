# %%
# Why do we need visualisation? summarisation of data
# Matplotlib,seabrn,plotly,bokeh
# Matplotlib >> Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python. Matplotlib makes easy things easy and hard things possible.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')#suppress all the warnings

# %%
#line,scatter, bar histagram, pie chart,box plot violin plot

# %%
#generate random number in numpy

x=np.random.rand(50)

# %%
x
# Out:
# array([0.13359343, 0.19270993, 0.88689996, 0.31577029, 0.43457497,
#        0.75352988, 0.65512894, 0.34199201, 0.44691866, 0.13078168,
#        0.25938911, 0.05425102, 0.60587245, 0.91935911, 0.50608042,
#        0.32815994, 0.5440575 , 0.65327616, 0.32367077, 0.11902419,
#        0.25398954, 0.11942013, 0.51751938, 0.45931035, 0.75578506,
#        0.09717733, 0.80973748, 0.34295373, 0.78693244, 0.27218254,
#        0.61326136, 0.58865012, 0.94653722, 0.87993682, 0.54658473,
#        0.94979311, 0.82968443, 0.90330026, 0.88540432, 0.18048342,
#        0.40881507, 0.00234079, 0.39649981, 0.61467462, 0.19420458,
#        0.25858178, 0.98055884, 0.26612723, 0.7369512 , 0.13505675])

# %%
len(x)
# Out:
# 50

# %%
np.random.randn(50)
# Out:
# array([ 0.6971651 , -3.0886161 ,  1.56998411,  0.42398026, -0.37032412,
#         0.60446971,  0.37537334, -0.84018589,  1.09232397, -0.55598244,
#        -0.39703742, -0.80931363, -0.15585284, -0.56266591,  1.12955958,
#        -0.73581823, -0.2378174 , -1.47867609, -0.42409046,  0.34966839,
#         1.4636046 ,  1.03278252,  0.0293357 , -1.04086376,  0.92763255,
#        -1.81082368,  1.06675326, -0.31195359,  1.64127015,  0.13749236,
#        -0.68521877, -0.53742332,  0.62589273,  0.89873547, -0.93413612,
#         0.80847112, -2.40039282, -0.48538617,  0.87042405, -1.66381423,
#         1.21383987, -0.48872829,  0.21264685, -1.05702718, -0.44993822,
#         1.58478169, -2.22039429, -1.35569911, -0.9335609 , -0.54540785])

# %%
df=pd.DataFrame(np.random.randn(1000),columns=['Data'],index=pd.date_range('2024-07-11',periods=1000))

# %%
df
# Out:
#                 Data
# 2024-07-11 -0.492622
# 2024-07-12 -2.004598
# 2024-07-13 -0.999771
# 2024-07-14  0.147152
# 2024-07-15 -0.792522
# ...              ...
# 2027-04-02  0.712981
# 2027-04-03  0.342521
# 2027-04-04  0.061851
# 2027-04-05  0.172836
# 2027-04-06 -0.362909
#
# [1000 rows x 1 columns]

# %%
df.plot(figsize=(20,8))#most of the values are fluctuating between-2 and 2
# Out:
# <Axes: >

# %%
x
# Out:
# array([0.13359343, 0.19270993, 0.88689996, 0.31577029, 0.43457497,
#        0.75352988, 0.65512894, 0.34199201, 0.44691866, 0.13078168,
#        0.25938911, 0.05425102, 0.60587245, 0.91935911, 0.50608042,
#        0.32815994, 0.5440575 , 0.65327616, 0.32367077, 0.11902419,
#        0.25398954, 0.11942013, 0.51751938, 0.45931035, 0.75578506,
#        0.09717733, 0.80973748, 0.34295373, 0.78693244, 0.27218254,
#        0.61326136, 0.58865012, 0.94653722, 0.87993682, 0.54658473,
#        0.94979311, 0.82968443, 0.90330026, 0.88540432, 0.18048342,
#        0.40881507, 0.00234079, 0.39649981, 0.61467462, 0.19420458,
#        0.25858178, 0.98055884, 0.26612723, 0.7369512 , 0.13505675])

# %%
y=np.random.rand(50)

# %%
y
# Out:
# array([0.8097326 , 0.83743538, 0.15289704, 0.04713798, 0.40180501,
#        0.21123653, 0.99920413, 0.85198834, 0.49771474, 0.05028515,
#        0.24445078, 0.87283224, 0.67384868, 0.23843188, 0.52611084,
#        0.67052066, 0.13382967, 0.66644401, 0.17124403, 0.29520699,
#        0.64910818, 0.91484447, 0.56959146, 0.8483607 , 0.03366535,
#        0.72301648, 0.16260967, 0.30817203, 0.4275335 , 0.36450239,
#        0.16663641, 0.42243215, 0.29221077, 0.15101727, 0.20692244,
#        0.79686554, 0.4214966 , 0.58117104, 0.64745708, 0.53992935,
#        0.36350153, 0.91425472, 0.76934358, 0.43821113, 0.11232623,
#        0.40386372, 0.73737832, 0.61272695, 0.72028789, 0.92742764])

# %%
#scatter plot>>A scatter plot is a type of graph used to display the relationship between two numerical variables. In a scatter plot, each point represents an observation in a dataset, with its position determined by values on the x-axis (horizontal) and y-axis (vertical). Scatter plots are particularly useful for identifying correlations, trends, or patterns between the two variables. 
plt.scatter(x,y)

# %%
#line plot
#whenever you wand to depict the relation between two variables in the form of trend
#mostly in x acis the date-time column is there
x=[1,2,3,4,5]#assume x is no of day
y=[5,2,7,8,1]#y is price of stock

# %%
x
# Out:
# [1, 2, 3, 4, 5]

# %%
y
# Out:
# [5, 2, 7, 8, 1]

# %%
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
plt.show()

# %%
plt.plot(x,y,color="red",marker="o",linestyle='--')
plt.title("line chart to understand tee syntax")
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
plt.show()

# %%
plt.plot(x,y,color="red",marker="o",linestyle='--',linewidth=4)
plt.title("line chart to understand  syntax")
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
plt.show()

# %%
plt.plot(x,y,color="red",marker="o",linestyle='--',linewidth=4,markersize=15)
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
plt.show()

# %%
plt.plot(x,y,color="red",marker="o",linestyle='--',linewidth=4,markersize=10)
plt.xlabel("day interval as x points")
plt.ylabel("price as y points")
plt.grid()
plt.show()

# %%
x=[1,2,3,4,5]
y1=[5,1,7,8,2]
y2=[7,8,3,5,1]

plt.plot(x,y1,color="red",marker="o",linestyle="--",linewidth=3,markersize=6,label="line y1 as tata motors")
plt.plot(x,y2,color="b",marker="o",linestyle="--",linewidth=3,markersize=6,label="line y2 as tata power")

plt.title("multiple line in one plot")
plt.xlabel("Days")
plt.ylabel("stock price")
plt.legend()

plt.show()

# %%
x=np.linspace(0,10,100)
plt.plot(x,np.sin(x))
plt.plot(x,np.cos(x))

# %%
plt.plot(x,np.sin(x),'--')

# %%
plt.plot(x,np.sin(x),':')

# %%
plt.figure() #Initialising a page to make plot
plt.subplot(1,2,1)
plt.plot(x,np.sin(x))

plt.subplot(1,2,2)
plt.plot(x,np.cos(x))

plt.show()

# %%
plt.figure()#initialising a page to make plot
plt.subplot(2,1,1)
plt.plot(x,np.sin(x))

plt.subplot(2,1,2)
plt.plot(x,np.cos(x))

plt.show()

# %%
plt.figure()
plt.subplot(2,2,1)
plt.plot(x,np.sin(x))

plt.subplot(2,2,2)
plt.plot(x,np.cos(x))

plt.subplot(2,2,3)
plt.plot(x,np.tan(x))

plt.subplot(2,2,4)
plt.plot(x,np.sin(x+1),color='b')

plt.show()

# %%
plt.plot(x,np.sin(x-0),color='blue')
plt.ylim(-1.5,1.5)
plt.xlim(1,15)
plt.show()

# %%
plt.plot(x,np.sin(x-0),color='blue')
plt.ylim(-1.5,1.5)
plt.xlim(1,15)
plt.axis('equal')
plt.show()

# %%
plt.plot(x,np.sin(x-0),color='blue')
plt.ylim(-1.5,1.5)
plt.xlim(1,15)
plt.axis('equal')
plt.grid()
plt.show()

# %%
plt.plot(x,np.sin(x-0),color='blue')
plt.ylim(-1.5,1.5)
plt.xlim(1,15)
plt.title("basic syntax")
plt.xlabel("x label")
plt.ylabel("y label")
plt.axis('equal')
plt.grid()
plt.show()

# %%
#histogram>>continuous numerical data

data=np.random.randn(1000)#by default 10 bins are created
plt.hist(data)
plt.show()

# %%
data=np.random.randn(1000)
plt.hist(data,color='r',bins=20)
plt.show()

# %%
#stacked histofram>>two histograms together
data1=np.random.normal(0,1,5000)
data2=np.random.normal(3,2,5000)

# %%
data1
# Out:
# array([ 1.1859332 ,  1.68580525,  0.20988717, ..., -0.37089447,
#        -2.2211335 , -0.51951639])

# %%
data2
# Out:
# array([1.11642711, 6.70823118, 5.45941098, ..., 3.90513522, 5.20076551,
#        5.35345798])

# %%
plt.hist([data1,data2], bins=20, color = ['r','b'], label = ['dist1','dist2'])
plt.xlabel("Values")
plt.ylabel('frequency')
plt.title("stacked histogram")
# Out:
# Text(0.5, 1.0, 'stacked histogram')

# %%
#scatterplot>>to understand the relationship between two features
x= np.random.rand(50)
y= np.random.rand(50)

# %%
x
# Out:
# array([0.52420806, 0.3496758 , 0.64925636, 0.46908964, 0.72902786,
#        0.53586019, 0.0169397 , 0.62748362, 0.46378626, 0.64154331,
#        0.55424087, 0.40906915, 0.24895561, 0.25667568, 0.85816243,
#        0.66522065, 0.026967  , 0.33978919, 0.8354366 , 0.01560428,
#        0.63895408, 0.96767485, 0.39071252, 0.92574434, 0.88695627,
#        0.27243088, 0.38536809, 0.19865716, 0.09335941, 0.79749616,
#        0.99935286, 0.09383552, 0.38132021, 0.75772762, 0.54867749,
#        0.4544317 , 0.74953174, 0.08329007, 0.52454068, 0.23261667,
#        0.01721162, 0.64233744, 0.55416664, 0.79490523, 0.9684914 ,
#        0.86431739, 0.72068302, 0.20426511, 0.56674461, 0.60711486])

# %%
y
# Out:
# array([0.56546634, 0.22844435, 0.40393816, 0.47112029, 0.16435404,
#        0.2201973 , 0.69075658, 0.78027429, 0.43596676, 0.86452944,
#        0.20291171, 0.89743945, 0.63938715, 0.3260153 , 0.67310856,
#        0.54238972, 0.66721303, 0.16510912, 0.22370527, 0.86054625,
#        0.20170904, 0.33076642, 0.98405561, 0.22609188, 0.77022794,
#        0.11203469, 0.37714505, 0.81932536, 0.73852535, 0.82471177,
#        0.26322891, 0.79489057, 0.46017445, 0.41758218, 0.37741822,
#        0.00165455, 0.99432073, 0.93971462, 0.39616612, 0.19747104,
#        0.93543993, 0.29942679, 0.6876309 , 0.482866  , 0.7201059 ,
#        0.39365477, 0.02739519, 0.60385583, 0.0358856 , 0.80036436])

# %%
plt.scatter(x,y)

# %%
plt.scatter(x,y, c='r',marker="*")

# %%
#bar plot>>to see teh districution of categorical variables
x=["a","b","c","d"]#name of students 
y=[4,6,1,10]#no of days present in the calss

plt.bar(x,y,color='r')#vertical plot
# Out:
# <BarContainer object of 4 artists>

# %%
#bar plot>>to see teh districution of categorical variables
x=["a","b","c","d"]#name of students 
y=[4,6,1,10]#no of days present in the calss

plt.barh(x,y,color='r')#horizontal plot
# Out:
# <BarContainer object of 4 artists>

# %%
#pie chart>>To understand the percent distrubution of data
langs=["c","python","java"]
students=[20,100,40]

plt.pie(students,labels=langs,autopct="%1.1f%%")
plt.title("pie chart")
plt.show()

# %%
#focus on one segment
explode=(0.0,0.1,0.1)
langs=["c","python","java"]
students=[20,100,40]

plt.pie(students,labels=langs,autopct="%1.1f%%",explode=explode)
plt.title("pie chart")
plt.show()

# %%
explode=(0.0,0.1,0.1)
langs=["c","python","java"]
students=[20,100,40]

plt.pie(students,labels=langs,autopct="%1.1f%%",explode=explode,shadow=True)
plt.title("pie chart")
plt.show()

# %%
#3d plot
x=np.random.rand(20)
y=np.random.rand(20)
z=np.random.rand(20)

fig=plt.figure()
ax=fig.add_subplot(projection='3d')
ax.scatter(x,y,z,c='r')

# %%
data=pd.read_csv("Bank_churn.csv")

# %%
data
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
plt.scatter(x=data['Age'],y=data["Balance"])

# %%
data.plot.scatter(x='Age',y='Balance')
# Out:
# <Axes: xlabel='Age', ylabel='Balance'>

# %%
plt.hist(data['Age'])
# Out:
# (array([ 611., 2179., 3629., 1871.,  828.,  523.,  208.,  127.,   20.,
#            4.]),
#  array([18. , 25.4, 32.8, 40.2, 47.6, 55. , 62.4, 69.8, 77.2, 84.6, 92. ]),
#  <BarContainer object of 10 artists>)

# %%
#Boxplot>>to check the distribution of data and outliers(extreme/abnormal values)
data.boxplot(column='Balance')
# Out:
# <Axes: >

# %%
plt.violinplot(data['Balance'])
# Out:
# {'bodies': [<matplotlib.collections.FillBetweenPolyCollection at 0x175273470>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x17733b5c0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x177959ca0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1776798b0>}

# %%
#area plot
years=[2021,2018,2022,2023,2017]
category1=[20,25,30,28,35]
category2=[10,15,20,18,25]
category3=[5,8,10,9,15]

plt.stackplot(years,category1,category2,category3,labels=["category1","category2","category3"],colors=["skyblue","lightgreen","orange"])
plt.xlabel("years")
plt.ylabel("values")
plt.title("Area plot")
plt.legend()
plt.show()
